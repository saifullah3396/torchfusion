# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of torchfusion.core.data.args.data_args failed: Traceback (most recent call last):
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 3 free vars, not 2
# ]
# [autoreload of torchfusion.core.args.args failed: Traceback (most recent call last):
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/ataraxia/.virtualenvs/torchfusion/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 2
# ]

# %%
import os 
import sys 

os.environ['DATA_ROOT_DIR'] = '/home/ataraxia/Datasets/'
os.environ['TORCH_FUSION_CACHE_DIR'] = '/home/ataraxia/torchfusion/cache/'
os.environ['TORCH_FUSION_OUTPUT_DIR'] = '/home/ataraxia/torchfusion/output/torchfusion'

PATH_TO_SOURCE_DIR = os.path.abspath("../../../src/")
PATH_TO_CONFIGS_DIR = os.path.abspath("../../../cfg/")
sys.path.append(PATH_TO_SOURCE_DIR)

print("Adding source path: ", PATH_TO_SOURCE_DIR)
print("Using configs path: ", PATH_TO_CONFIGS_DIR)
# Out:
# Adding source path:  /home/ataraxia/Projects/torchfusionv2/src
# Using configs path:  /home/ataraxia/Projects/torchfusionv2/cfg

# %%
from torchfusion.core.training.utilities.constants import TrainingStage
from hydra import compose, initialize, initialize_config_dir
from hydra.core.global_hydra import GlobalHydra
from omegaconf import OmegaConf
from hydra.core.hydra_config import HydraConfig
from torchfusion.core.args.args import FusionArguments
from torchfusion.utilities.dataclasses.dacite_wrapper import from_dict
from torchfusion.core.training.fusion_trainer import FusionTrainer

# %%
def initialize_hydra(config_path:str):
    # clear previous instances of hydra
    GlobalHydra.instance().clear() 

    # initialize hydra
    initialize_config_dir(version_base=None, config_dir=f"{PATH_TO_CONFIGS_DIR}/{config_path}")

    # compose a hydra config from the path given
    overrides = [
        "args/data_args=datasets/image_classification/tobacco3482", # prepare cifar10
    ]
    cfg = compose(config_name="prepare_datasets.yaml", overrides=overrides, return_hydra_config=True)
    hydra_config = cfg['hydra']
    hydra_config.runtime.output_dir = './'
    cfg = OmegaConf.to_object(cfg['args'])
    
    # # in case of notebooks we remove the analyzer arguments as the notebook itself runs the analysis code
    # args = from_dict(data_class=FusionArguments, data=cfg)   
    
    # # set tb logger to off
    # args.training_args.log_to_tb = False
    
    # # you can update args here
    # # for example set train_val_sampler to None
    # args.train_val_sampler = None
    
    # # print the default config that we received
    # print ("Using the following configuration: ")
    # print(args)
    
    return args, hydra_config
    
args, hydra_config = initialize_hydra("defaults")
# Out:
# ---------------------------------------------------------------------------
# MissingConfigException                    Traceback (most recent call last)
# Cell In[18], line 33
#      17     # # in case of notebooks we remove the analyzer arguments as the notebook itself runs the analysis code
#      18     # args = from_dict(data_class=FusionArguments, data=cfg)
#      19
#    (...)
#      28     # print ("Using the following configuration: ")
#      29     # print(args)
#      31     return args, hydra_config
# ---> 33 args, hydra_config = initialize_hydra("defaults")
#
# Cell In[18], line 12, in initialize_hydra(config_path)
#       8 # compose a hydra config from the path given
#       9 overrides = [
#      10     "args/data_args=datasets/image_classification/tobacco3482", # prepare cifar10
#      11 ]
# ---> 12 cfg = compose(config_name="prepare_datasets.yaml", overrides=overrides, return_hydra_config=True)
#      13 hydra_config = cfg['hydra']
#      14 hydra_config.runtime.output_dir = './'
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/compose.py:38, in compose(config_name, overrides, return_hydra_config, strict)
#      36 gh = GlobalHydra.instance()
#      37 assert gh.hydra is not None
# ---> 38 cfg = gh.hydra.compose_config(
#      39     config_name=config_name,
#      40     overrides=overrides,
#      41     run_mode=RunMode.RUN,
#      42     from_shell=False,
#      43     with_log_configuration=False,
#      44 )
#      45 assert isinstance(cfg, DictConfig)
#      47 if not return_hydra_config:
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/hydra.py:594, in Hydra.compose_config(self, config_name, overrides, run_mode, with_log_configuration, from_shell, validate_sweep_overrides)
#     576 def compose_config(
#     577     self,
#     578     config_name: Optional[str],
#    (...)
#     583     validate_sweep_overrides: bool = True,
#     584 ) -> DictConfig:
#     585     """
#     586     :param config_name:
#     587     :param overrides:
#    (...)
#     591     :return:
#     592     """
# --> 594     cfg = self.config_loader.load_configuration(
#     595         config_name=config_name,
#     596         overrides=overrides,
#     597         run_mode=run_mode,
#     598         from_shell=from_shell,
#     599         validate_sweep_overrides=validate_sweep_overrides,
#     600     )
#     601     if with_log_configuration:
#     602         configure_log(cfg.hydra.hydra_logging, cfg.hydra.verbose)
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/config_loader_impl.py:142, in ConfigLoaderImpl.load_configuration(self, config_name, overrides, run_mode, from_shell, validate_sweep_overrides)
#     133 def load_configuration(
#     134     self,
#     135     config_name: Optional[str],
#    (...)
#     139     validate_sweep_overrides: bool = True,
#     140 ) -> DictConfig:
#     141     try:
# --> 142         return self._load_configuration_impl(
#     143             config_name=config_name,
#     144             overrides=overrides,
#     145             run_mode=run_mode,
#     146             from_shell=from_shell,
#     147             validate_sweep_overrides=validate_sweep_overrides,
#     148         )
#     149     except OmegaConfBaseException as e:
#     150         raise ConfigCompositionException().with_traceback(sys.exc_info()[2]) from e
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/config_loader_impl.py:253, in ConfigLoaderImpl._load_configuration_impl(self, config_name, overrides, run_mode, from_shell, validate_sweep_overrides)
#     248 if validate_sweep_overrides:
#     249     self.validate_sweep_overrides_legal(
#     250         overrides=parsed_overrides, run_mode=run_mode, from_shell=from_shell
#     251     )
# --> 253 defaults_list = create_defaults_list(
#     254     repo=caching_repo,
#     255     config_name=config_name,
#     256     overrides_list=parsed_overrides,
#     257     prepend_hydra=True,
#     258     skip_missing=run_mode == RunMode.MULTIRUN,
#     259 )
#     261 config_overrides = defaults_list.config_overrides
#     263 cfg = self._compose_config_from_defaults_list(
#     264     defaults=defaults_list.defaults, repo=caching_repo
#     265 )
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:745, in create_defaults_list(repo, config_name, overrides_list, prepend_hydra, skip_missing)
#     736 """
#     737 :param repo:
#     738 :param config_name:
#    (...)
#     742 :return:
#     743 """
#     744 overrides = Overrides(repo=repo, overrides_list=overrides_list)
# --> 745 defaults, tree = _create_defaults_list(
#     746     repo,
#     747     config_name,
#     748     overrides,
#     749     prepend_hydra=prepend_hydra,
#     750     skip_missing=skip_missing,
#     751 )
#     752 overrides.ensure_overrides_used()
#     753 overrides.ensure_deletions_used()
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:715, in _create_defaults_list(repo, config_name, overrides, prepend_hydra, skip_missing)
#     706 def _create_defaults_list(
#     707     repo: IConfigRepository,
#     708     config_name: Optional[str],
#    (...)
#     711     skip_missing: bool,
#     712 ) -> Tuple[List[ResultDefault], DefaultsTreeNode]:
#     713     root = _create_root(config_name=config_name, with_hydra=prepend_hydra)
# --> 715     defaults_tree = _create_defaults_tree(
#     716         repo=repo,
#     717         root=root,
#     718         overrides=overrides,
#     719         is_root_config=True,
#     720         interpolated_subtree=False,
#     721         skip_missing=skip_missing,
#     722     )
#     724     output = _tree_to_list(tree=defaults_tree)
#     725     ensure_no_duplicates_in_list(output)
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:356, in _create_defaults_tree(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     348 def _create_defaults_tree(
#     349     repo: IConfigRepository,
#     350     root: DefaultsTreeNode,
#    (...)
#     354     overrides: Overrides,
#     355 ) -> DefaultsTreeNode:
# --> 356     ret = _create_defaults_tree_impl(
#     357         repo=repo,
#     358         root=root,
#     359         is_root_config=is_root_config,
#     360         skip_missing=skip_missing,
#     361         interpolated_subtree=interpolated_subtree,
#     362         overrides=overrides,
#     363     )
#     365     return ret
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:457, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     455 if parent.is_virtual():
#     456     if is_root_config:
# --> 457         return _expand_virtual_root(repo, root, overrides, skip_missing)
#     458     else:
#     459         return root
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:280, in _expand_virtual_root(repo, root, overrides, skip_missing)
#     277 new_root = DefaultsTreeNode(node=d, parent=root)
#     278 d.update_parent("", "")
# --> 280 subtree = _create_defaults_tree_impl(
#     281     repo=repo,
#     282     root=new_root,
#     283     is_root_config=d.primary,
#     284     skip_missing=skip_missing,
#     285     interpolated_subtree=False,
#     286     overrides=overrides,
#     287 )
#     288 if subtree.children is None:
#     289     children.append(d)
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:573, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     570                 continue
#     572             new_root = DefaultsTreeNode(node=d, parent=root)
# --> 573             add_child(children, new_root)
#     575 # processed deferred interpolations
#     576 known_choices = _create_interpolation_map(overrides, defaults_list, self_added)
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:520, in _create_defaults_tree_impl.<locals>.add_child(child_list, new_root_)
#     516 def add_child(
#     517     child_list: List[Union[InputDefault, DefaultsTreeNode]],
#     518     new_root_: DefaultsTreeNode,
#     519 ) -> None:
# --> 520     subtree_ = _create_defaults_tree_impl(
#     521         repo=repo,
#     522         root=new_root_,
#     523         is_root_config=False,
#     524         interpolated_subtree=interpolated_subtree,
#     525         skip_missing=skip_missing,
#     526         overrides=overrides,
#     527     )
#     528     if subtree_.children is None:
#     529         child_list.append(new_root_.node)
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:573, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     570                 continue
#     572             new_root = DefaultsTreeNode(node=d, parent=root)
# --> 573             add_child(children, new_root)
#     575 # processed deferred interpolations
#     576 known_choices = _create_interpolation_map(overrides, defaults_list, self_added)
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:520, in _create_defaults_tree_impl.<locals>.add_child(child_list, new_root_)
#     516 def add_child(
#     517     child_list: List[Union[InputDefault, DefaultsTreeNode]],
#     518     new_root_: DefaultsTreeNode,
#     519 ) -> None:
# --> 520     subtree_ = _create_defaults_tree_impl(
#     521         repo=repo,
#     522         root=new_root_,
#     523         is_root_config=False,
#     524         interpolated_subtree=interpolated_subtree,
#     525         skip_missing=skip_missing,
#     526         overrides=overrides,
#     527     )
#     528     if subtree_.children is None:
#     529         child_list.append(new_root_.node)
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:488, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     486         parent.deleted = True
#     487         return root
# --> 488     config_not_found_error(repo=repo, tree=root)
#     490 assert loaded is not None
#     491 defaults_list = copy.deepcopy(loaded.defaults_list)
#
# File ~/.virtualenvs/torchfusion/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:799, in config_not_found_error(repo, tree)
#     796 lines = "\n".join(descs)
#     797 msg += "\nConfig search path:" + f"\n{lines}"
# --> 799 raise MissingConfigException(
#     800     missing_cfg_file=element.get_config_path(),
#     801     message=msg,
#     802     options=options,
#     803 )
#
# MissingConfigException: In 'args/data_args/datasets/image_classification/tobacco3482': Could not find 'args/data_args/train_val_sampler/random_split'
#
# Config search path:
# 	provider=hydra, path=pkg://hydra.conf
# 	provider=main, path=file:///home/ataraxia/Projects/torchfusionv2/cfg/defaults
# 	provider=schema, path=structured://

# %%
from dataclasses import dataclass, field
from typing import Optional
import torch
import numpy as np
from torch.utils.data import Subset
from torchvision.transforms import Compose, ToTensor, Normalize, RandomHorizontalFlip, RandomCrop, Resize
from torchfusion.core.constants import DataKeys
from torchfusion.core.data.data_augmentations.general import DictTransform
from torchfusion.core.data.utilities.containers import TransformsDict
from torchfusion.core.models.utilities.data_collators import BatchToTensorDataCollator
from torchfusion.utilities.logging import get_logger

def get_trainer(pretrained_checkpoint=None, transforms=None):
    trainer = FusionTrainer(args, hydra_config=hydra_config)

    # setup training
    trainer._setup_training(setup_tb_logger=False)

    # setup datamodule
    trainer._datamodule = trainer._setup_datamodule(stage=None, realtime_transforms=transforms)
        
    # setup dataloaders
    trainer._args.data_loader_args.per_device_train_batch_size = 32
    trainer._args.data_loader_args.per_device_eval_batch_size = 32
    trainer._args.data_loader_args.dataloader_num_workers = 1
    trainer._test_dataloader = trainer._datamodule.test_dataloader(
        trainer._args.data_loader_args.per_device_eval_batch_size,
        dataloader_num_workers=trainer._args.data_loader_args.dataloader_num_workers,
        pin_memory=trainer._args.data_loader_args.pin_memory,
    )
    
    return trainer

# create custom transforms. If not provided, transforms defined in the configuration file will be used
transforms = TransformsDict()
transforms.train = Compose([
    DictTransform(key=DataKeys.IMAGE, transform=[RandomHorizontalFlip(), RandomCrop(32, padding=4), ToTensor()]),
])
transforms.validation = Compose([
    DictTransform(key=DataKeys.IMAGE, transform=ToTensor()),
])
transforms.test = Compose([
    DictTransform(key=DataKeys.IMAGE, transform=ToTensor()),
])

trainer = get_trainer(transforms=None)
# Out:
# 2024-04-17 19:34:44 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Global seed set to 42
# 2024-04-17 19:34:44 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Setting output directory: ./
# 2024-04-17 19:34:44 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Setting up datamodule...
# 2024-04-17 19:34:44 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Defining [train] realtime transforms:
# 2024-04-17 19:34:44 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO 0, ['image']: Compose(
#     ToTensor()
#     GrayScaleToRGB()
#     Rescale(size=[224, 224], interpolation='bilinear', max_size=None, antialias=False)
#     ConvertImageDtype()
#     Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
# )
# 2024-04-17 19:34:44 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Defining [validation] realtime transforms:
# 2024-04-17 19:34:44 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO 0, ['image']: Compose(
#     ToTensor()
#     GrayScaleToRGB()
#     Rescale(size=[224, 224], interpolation='bilinear', max_size=None, antialias=False)
#     ConvertImageDtype()
#     Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
# )
# 2024-04-17 19:34:44 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Defining [test] realtime transforms:
# 2024-04-17 19:34:44 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO 0, ['image']: Compose(
#     ToTensor()
#     GrayScaleToRGB()
#     Rescale(size=[224, 224], interpolation='bilinear', max_size=None, antialias=False)
#     ConvertImageDtype()
#     Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
# )
# 2024-04-17 19:34:44 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Loading data for stage == train|test|val
# Files already downloaded and verified
# 2024-04-17 19:34:45 ataraxia-B450-AORUS-ELITE torchfusion[29925] WARNING Using train set as validation set as no validation dataset exists. If this behavior is not required set, do_val=False in config.
# 2024-04-17 19:34:45 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Training set size = 50000
# 2024-04-17 19:34:45 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Validation set size = 50000
# Files already downloaded and verified
# 2024-04-17 19:34:45 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Test set size = 10000
# 2024-04-17 19:34:45 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Dataset loaded with following features: {'label': ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']}
# 2024-04-17 19:34:45 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Number of labels = 10
# 2024-04-17 19:34:45,607 ignite.distributed.auto.auto_dataloader INFO: Use data loader kwargs for dataset '<torchfusion.data.da':
# 	{'sampler': <torch.utils.data.sampler.SequentialSampler object at 0x7f04458cf8b0>, 'batch_size': 32, 'collate_fn': BatchToTensorDataCollator(allowed_keys=None, type_map=None), 'num_workers': 1, 'pin_memory': True, 'shuffle': False, 'drop_last': False}

# %%
# setup dataloaders
trainer._datamodule._collate_fns.test = BatchToTensorDataCollator(type_map={'image': torch.float32, 'label': torch.long})
with torch.no_grad():
    for batch in trainer._test_dataloader:
        image = batch['image']
        image = image.cuda()
        trainer._datamodule.show_batch(batch)
        break
# Out:
# 2024-04-17 19:35:13 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Batch information:
# 2024-04-17 19:35:13 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Batch element=image, shape=torch.Size([32, 3, 224, 224]), type=torch.float32
# Example: tensor([[[ 0.5878,  0.5878,  0.5878,  ..., -0.1314, -0.1314, -0.1314],
#          [ 0.5878,  0.5878,  0.5878,  ..., -0.1314, -0.1314, -0.1314],
#          [ 0.5878,  0.5878,  0.5878,  ..., -0.1314, -0.1314, -0.1314],
#          ...,
#          [-1.1932, -1.1932, -1.1932,  ..., -1.7583, -1.7583, -1.7583],
#          [-1.1932, -1.1932, -1.1932,  ..., -1.7583, -1.7583, -1.7583],
#          [-1.1932, -1.1932, -1.1932,  ..., -1.7583, -1.7583, -1.7583]],
#
#         [[-0.0749, -0.0749, -0.0749,  ..., -0.5476, -0.5476, -0.5476],
#          [-0.0749, -0.0749, -0.0749,  ..., -0.5476, -0.5476, -0.5476],
#          [-0.0749, -0.0749, -0.0749,  ..., -0.5476, -0.5476, -0.5476],
#          ...,
#          [-0.1625, -0.1625, -0.1625,  ..., -0.8627, -0.8627, -0.8627],
#          [-0.1625, -0.1625, -0.1625,  ..., -0.8627, -0.8627, -0.8627],
#          [-0.1625, -0.1625, -0.1625,  ..., -0.8627, -0.8627, -0.8627]],
#
#         [[-0.9504, -0.9504, -0.9504,  ..., -1.2293, -1.2293, -1.2293],
#          [-0.9504, -0.9504, -0.9504,  ..., -1.2293, -1.2293, -1.2293],
#          [-0.9504, -0.9504, -0.9504,  ..., -1.2293, -1.2293, -1.2293],
#          ...,
#          [ 0.9842,  0.9842,  0.9842,  ...,  0.1128,  0.1128,  0.1128],
#          [ 0.9842,  0.9842,  0.9842,  ...,  0.1128,  0.1128,  0.1128],
#          [ 0.9842,  0.9842,  0.9842,  ...,  0.1128,  0.1128,  0.1128]]])
# 2024-04-17 19:35:13 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Batch element=label, shape=torch.Size([32]), type=torch.int64
# Example: 3
# 2024-04-17 19:35:13 ataraxia-B450-AORUS-ELITE torchfusion[29925] INFO Batch element=index, shape=torch.Size([32]), type=torch.int64
# Example: 0
# 2024-04-17 19:35:13 ataraxia-B450-AORUS-ELITE torchfusion[29925] WARNING Showing only first 4 images in the batch as high-resolution images may take too much memory...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
